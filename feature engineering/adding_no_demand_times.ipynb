# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
zero_df = pd.read_csv("zero_df.csv")

# %%
zero_df = zero_df.drop(['Unnamed: 0'], axis=1)

# %%
zero_df['hour_of_day'] = [r.hour for r in pd.to_datetime(zero_df.Datetime)]
zero_df['month'] = [r.month for r in pd.to_datetime(zero_df.Datetime)]

# %%
zero_df['Datetime'] = pd.to_datetime(zero_df['Datetime'])

# %%
zero_df['date_only'] = zero_df['Datetime'].dt.date
zero_df['date_only'] = pd.to_datetime(zero_df['date_only'])

# %%
weather = pd.read_csv('../data/raw_data/weather_clean.csv')

# %%
weather.DATE.describe()
weather['DATE'] = pd.to_datetime(weather['DATE'])

# %%
zero_df = zero_df.merge(weather, how='left',left_on='date_only', right_on='DATE')

# %%
weather
# Out:
#       Unnamed: 0       DATE  AVG_WND_SPEED  PRCP  SNOW  SNOW_DEPTH  TAVG  \
# 0             53 2015-04-23          15.21  0.00   0.0         0.0  48.0
# 1             54 2015-04-24          16.55  0.00   0.0         0.0  47.0
# 2             55 2015-04-25           9.17  0.00   0.0         0.0  48.0
# 3             56 2015-04-26           7.38  0.00   0.0         0.0  54.0
# 4             57 2015-04-27          11.18  0.00   0.0         0.0  54.0
# ...          ...        ...            ...   ...   ...         ...   ...
# 1618        1671 2019-09-27           4.92  0.00   0.0         0.0  69.0
# 1619        1672 2019-09-28           6.71  0.16   0.0         0.0  72.0
# 1620        1673 2019-09-29           7.16  0.00   0.0         0.0  76.0
# 1621        1674 2019-09-30           7.61  0.00   0.0         0.0  69.0
# 1622        1675 2019-10-01           8.28  0.00   0.0         0.0  71.0
#
#       TMAX  TMIN  FOG  THUNDER  SLEET_OR_HAIL
# ...

# %%
zero_df
# Out:
#                   Datetime  start_station_id  COUNT  Station_ID  \
# 0      2015-04-23 07:00:00            3004.0    0.0        3004
# 1      2015-04-24 00:00:00            3004.0    0.0        3004
# 2      2015-04-24 07:00:00            3004.0    0.0        3004
# 3      2015-04-25 04:00:00            3004.0    0.0        3004
# 4      2015-04-25 06:00:00            3004.0    0.0        3004
# ...                    ...               ...    ...         ...
# 708809 2019-09-28 08:00:00            3190.0    0.0        3190
# 708810 2019-09-29 02:00:00            3190.0    0.0        3190
# 708811 2019-09-29 21:00:00            3190.0    0.0        3190
# 708812 2019-09-30 00:00:00            3190.0    0.0        3190
# 708813 2019-09-30 02:00:00            3190.0    0.0        3190
#
#                              Station_Name Day of Go_live_date  Status  \
# 0       Municipal Services Building Plaza           4/23/2015  Active
# ...

# %%
df.columns.values
# Out:
# array(['Datetime', 'start_station_id', 'start_lat', 'start_lon',
#        'hour_of_day', 'COUNT', 'AVG_WND_SPEED', 'PRCP', 'SNOW',
#        'SNOW_DEPTH', 'TAVG', 'TMAX', 'TMIN', 'FOG', 'THUNDER',
#        'SLEET_OR_HAIL', 'month', 'count_range', 'WEEKDAY', 'HOLIDAY',
#        'Station_ID', 'Station_Name', 'Day of Go_live_date', 'Status',
#        'Neighborhood', 'Walk Score', 'Transit Score', 'Bike Score',
#        'Population'], dtype=object)

# %%
zero_df.columns.values
# Out:
# array(['Datetime', 'start_station_id', 'COUNT', 'Station_ID',
#        'Station_Name', 'Day of Go_live_date', 'Status', 'Neighborhood',
#        'Walk Score', 'Transit Score', 'Bike Score', 'Population',
#        'WEEKDAY', 'HOLIDAY', 'hour_of_day', 'month', 'DATE',
#        'AVG_WND_SPEED', 'PRCP', 'SNOW', 'SNOW_DEPTH', 'TAVG', 'TMAX',
#        'TMIN', 'FOG', 'THUNDER', 'SLEET_OR_HAIL'], dtype=object)

# %%
df = df.drop(['Datetime.1', 'start_station_id.1'], axis=1)

# %%
zero_df = zero_df.drop(['Unnamed: 0', 'date_only'], axis=1)

# %%
#'start_lat', 'start_lon' 'count_range'
station_info = df.drop_duplicates('start_station_id')

# %%
station_info = station_info[['start_station_id', 'start_lat', 'start_lon']]

# %%
station_info
# Out:
#          start_station_id  start_lat  start_lon
# 0                  3004.0  39.953780 -75.163740
# 15813              3005.0  39.947330 -75.144030
# 27384              3006.0  39.952200 -75.203110
# 43246              3007.0  39.945170 -75.159930
# 64938              3008.0  39.980820 -75.149730
# ...                   ...        ...        ...
# 1442457            3210.0  39.984921 -75.156677
# 1442785            3206.0  39.951740 -75.170631
# 1443131            3202.0  39.951340 -75.167580
# 1443472            3201.0  39.955231 -75.166199
# 1443664            3209.0  39.949001 -75.212784
#
# [146 rows x 3 columns]

# %%
zero_df = zero_df.merge(station_info, how='left',on='start_station_id')

# %%
zero_df
# Out:
#                   Datetime  start_station_id  COUNT  Station_ID  \
# 0      2015-04-23 07:00:00            3004.0    0.0        3004
# 1      2015-04-24 00:00:00            3004.0    0.0        3004
# 2      2015-04-24 07:00:00            3004.0    0.0        3004
# 3      2015-04-25 04:00:00            3004.0    0.0        3004
# 4      2015-04-25 06:00:00            3004.0    0.0        3004
# ...                    ...               ...    ...         ...
# 708809 2019-09-28 08:00:00            3190.0    0.0        3190
# 708810 2019-09-29 02:00:00            3190.0    0.0        3190
# 708811 2019-09-29 21:00:00            3190.0    0.0        3190
# 708812 2019-09-30 00:00:00            3190.0    0.0        3190
# 708813 2019-09-30 02:00:00            3190.0    0.0        3190
#
#                              Station_Name Day of Go_live_date  Status  \
# 0       Municipal Services Building Plaza           4/23/2015  Active
# ...

# %%
df
# Out:
#                     Datetime  start_station_id  start_lat  start_lon  \
# 0        2015-04-23 10:00:00            3004.0  39.953780 -75.163740
# 1        2015-04-23 12:00:00            3004.0  39.953780 -75.163740
# 2        2015-04-23 13:00:00            3004.0  39.953780 -75.163740
# 3        2015-04-23 14:00:00            3004.0  39.953780 -75.163740
# 4        2015-04-23 15:00:00            3004.0  39.953780 -75.163740
# ...                      ...               ...        ...        ...
# 1443802  2019-09-30 11:00:00            3209.0  39.949001 -75.212784
# 1443803  2019-09-30 12:00:00            3209.0  39.949001 -75.212784
# 1443804  2019-09-30 13:00:00            3209.0  39.949001 -75.212784
# 1443805  2019-09-30 14:00:00            3209.0  39.949001 -75.212784
# 1443806  2019-09-30 18:00:00            3209.0  39.949001 -75.212784
#
#         hour_of_day  COUNT  AVG_WND_SPEED  PRCP  SNOW  SNOW_DEPTH  ...  \
# ...

# %%
frames = [df, zero_df]
frames
result = pd.concat(frames)
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
result
# Out:
#         AVG_WND_SPEED  Bike Score  COUNT       DATE             Datetime  \
# 0               15.21        77.0    5.0        NaT  2015-04-23 10:00:00
# 1               15.21        77.0    3.0        NaT  2015-04-23 12:00:00
# 2               15.21        77.0    2.0        NaT  2015-04-23 13:00:00
# 3               15.21        77.0    1.0        NaT  2015-04-23 14:00:00
# 4               15.21        77.0    5.0        NaT  2015-04-23 15:00:00
# ...               ...         ...    ...        ...                  ...
# 708809           6.71        85.0    0.0 2019-09-28  2019-09-28 08:00:00
# 708810           7.16        85.0    0.0 2019-09-29  2019-09-29 02:00:00
# 708811           7.16        85.0    0.0 2019-09-29  2019-09-29 21:00:00
# 708812           7.61        85.0    0.0 2019-09-30  2019-09-30 00:00:00
# 708813           7.61        85.0    0.0 2019-09-30  2019-09-30 02:00:00
#
#        Day of Go_live_date  FOG  HOLIDAY        Neighborhood  PRCP  ...  TMIN  \
# ...

# %%
result.columns.values
# Out:
# array(['AVG_WND_SPEED', 'Bike Score', 'COUNT', 'DATE', 'Datetime',
#        'Day of Go_live_date', 'FOG', 'HOLIDAY', 'Neighborhood', 'PRCP',
#        'Population', 'SLEET_OR_HAIL', 'SNOW', 'SNOW_DEPTH', 'Station_ID',
#        'Station_Name', 'Status', 'TAVG', 'THUNDER', 'TMAX', 'TMIN',
#        'Transit Score', 'WEEKDAY', 'Walk Score', 'count_range',
#        'hour_of_day', 'month', 'start_lat', 'start_lon',
#        'start_station_id'], dtype=object)

# %%
result.set_index(['Datetime','start_station_id'], inplace=True, drop=False)

# %%
result
# Out:
#                                       AVG_WND_SPEED  Bike Score  COUNT  \
# Datetime            start_station_id
# 2015-04-23 10:00:00 3004.0                    15.21        77.0    5.0
# 2015-04-23 12:00:00 3004.0                    15.21        77.0    3.0
# 2015-04-23 13:00:00 3004.0                    15.21        77.0    2.0
# 2015-04-23 14:00:00 3004.0                    15.21        77.0    1.0
# 2015-04-23 15:00:00 3004.0                    15.21        77.0    5.0
# ...                                             ...         ...    ...
# 2019-09-28 08:00:00 3190.0                     6.71        85.0    0.0
# 2019-09-29 02:00:00 3190.0                     7.16        85.0    0.0
# 2019-09-29 21:00:00 3190.0                     7.16        85.0    0.0
# 2019-09-30 00:00:00 3190.0                     7.61        85.0    0.0
# 2019-09-30 02:00:00 3190.0                     7.61        85.0    0.0
#
#                                                  Datetime  FOG  HOLIDAY  \
# ...

# %%
result.to_csv("combined_df.csv")

# %%
result = pd.read_csv("combined_df.csv")
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
result.columns.values
# Out:
# array(['Datetime', 'start_station_id', 'AVG_WND_SPEED', 'Bike Score',
#        'COUNT', 'Datetime.1', 'FOG', 'HOLIDAY', 'Neighborhood', 'PRCP',
#        'Population', 'SLEET_OR_HAIL', 'SNOW', 'SNOW_DEPTH', 'TAVG',
#        'THUNDER', 'TMAX', 'TMIN', 'Transit Score', 'WEEKDAY',
#        'Walk Score', 'count_range', 'hour_of_day', 'month', 'start_lat',
#        'start_lon', 'start_station_id.1'], dtype=object)

# %%
result = result.drop(['start_station_id.1','Datetime.1' ], axis=1)

# %%
result = result.drop(['Day of Go_live_date', 'Station_Name', 'Status', 'DATE'], axis=1)

# %%
result
# Out:
#                     Datetime  start_station_id  AVG_WND_SPEED  Bike Score  \
# 0        2015-04-23 10:00:00            3004.0          15.21        77.0
# 1        2015-04-23 12:00:00            3004.0          15.21        77.0
# 2        2015-04-23 13:00:00            3004.0          15.21        77.0
# 3        2015-04-23 14:00:00            3004.0          15.21        77.0
# 4        2015-04-23 15:00:00            3004.0          15.21        77.0
# ...                      ...               ...            ...         ...
# 2152616  2019-09-28 08:00:00            3190.0           6.71        85.0
# 2152617  2019-09-29 02:00:00            3190.0           7.16        85.0
# 2152618  2019-09-29 21:00:00            3190.0           7.16        85.0
# 2152619  2019-09-30 00:00:00            3190.0           7.61        85.0
# 2152620  2019-09-30 02:00:00            3190.0           7.61        85.0
#
#          COUNT  FOG  HOLIDAY        Neighborhood  PRCP  Population  ...  TMAX  \
# ...

# %%
result['hour_of_day'] = [r.hour for r in pd.to_datetime(result.Datetime)]

# %%
result.COUNT.describe()
# Out:
# count    2.152621e+06
# mean     1.450573e+00
# std      1.867442e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      7.800000e+01
# Name: COUNT, dtype: float64

# %%
import numpy as np
bins = [0, .9, 4, 10, 20, np.inf]
names = ['0', '1-4', '5-10', '11-20', '21+']

result['COUNT_BINS'] = pd.cut(result['COUNT'], bins, labels=names)

# %%
import numpy as np
bins = [0, 1, 4, 10, np.inf]
names = ['0-1', '2-4', '5-10', '11+']

result['COUNT_BINS'] = pd.cut(result['COUNT'], bins, labels=names)

# %%
import numpy as np
bins = [0, 3, 6, 10, np.inf]
names = ['0-3', '4-6', '7-10', '11+']

result['COUNT_BINS'] = pd.cut(result['COUNT'], bins, labels=names)

# %%
import numpy as np
bins = [0, 2, 9, np.inf]
names = ['0-2', '3-9', '10+']

result['COUNT_BINS'] = pd.cut(result['COUNT'], bins, labels=names)

# %%
import numpy as np
bins = [0,  .9, 1,  2,  9, np.inf]
names = ['0', '1', '2','3-9', '10+']

result['COUNT_BINS'] = pd.cut(result['COUNT'], bins, labels=names)

# %%
result['COUNT']
# Out:
# 0          0.0
# 1          0.0
# 2          0.0
# 3          2.0
# 4          0.0
#           ...
# 1409630    1.0
# 1409631    1.0
# 1409632    2.0
# 1409633    0.0
# 1409634    0.0
# Name: COUNT, Length: 1409635, dtype: float64

# %%
result['COUNT_BINS']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3            2
# 4          NaN
#           ...
# 1409630      1
# 1409631      1
# 1409632      2
# 1409633    NaN
# 1409634    NaN
# Name: COUNT_BINS, Length: 1409635, dtype: category
# Categories (5, object): [0 < 1 < 2 < 3-9 < 10+]

# %%
np.where((result.COUNT ==0))
# Out:
# (array([1443807, 1443808, 1443809, ..., 2152618, 2152619, 2152620]),)

# %%
result.iloc[1443807]
# Out:
# AVG_WND_SPEED                     15.21
# Bike Score                           77
# COUNT                                 0
# Datetime            2015-04-23 07:00:00
# FOG                                   0
# HOLIDAY                           False
# Neighborhood               Logan Square
# PRCP                                  0
# Population                         5137
# SLEET_OR_HAIL                         0
# SNOW                                  0
# SNOW_DEPTH                            0
# TAVG                                 48
# THUNDER                               0
# TMAX                                 52
# TMIN                                 43
# Transit Score                       100
# WEEKDAY                               1
# Walk Score                           99
# count_range                         NaN
# hour_of_day                           7
# month                                 4
# start_lat                       39.9538
# ...

# %%
result.MultiIndex.sortlevel
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-b83f1036f8a8> in <module>
# ----> 1 result.MultiIndex.sortlevel
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'MultiIndex'

# %%
result = result.reset_index(drop=False)

# %%
result = result.sort_values(by=['Datetime', 'start_station_id'])

# %%
result = result.set_index(['Datetime', 'start_station_id'], drop=False)

# %%
result = result.drop(['index'], axis=1)

# %%
result
# Out:
#                     Datetime  start_station_id  AVG_WND_SPEED  Bike Score  \
# 0        2015-04-23 07:00:00            3004.0          15.21        77.0
# 1        2015-04-23 07:00:00            3006.0          15.21        97.0
# 2        2015-04-23 07:00:00            3013.0          15.21        87.0
# 3        2015-04-23 07:00:00            3018.0          15.21        78.0
# 4        2015-04-23 07:00:00            3024.0          15.21        93.0
# ...                      ...               ...            ...         ...
# 2152616  2019-09-30 23:00:00            3190.0           7.61        85.0
# 2152617  2019-09-30 23:00:00            3192.0           7.61        97.0
# 2152618  2019-09-30 23:00:00            3195.0           7.61        79.0
# 2152619  2019-09-30 23:00:00            3200.0           7.61        73.0
# 2152620  2019-09-30 23:00:00            3209.0           7.61        99.0
#
#          COUNT  FOG  HOLIDAY                   Neighborhood  PRCP  Population  \
# ...

# %%
result['COUNT_BINS'] = result['COUNT_BINS'].fillna('0')

# %%
result['COUNT_BINS'].values_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-dd1e2b7d8bc6> in <module>
# ----> 1 result['COUNT_BINS'].values_count()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'values_count'

# %%
import numpy as np
arr = np.where([result.COUNT_BINS == '0'])
len(arr[0])
# Out:
# 4086

# %%
result.to_csv("result3.csv")

# %%
df1 = result[result.isna().any(axis=1)]

# %%
result = result.drop(['count_range'], axis=1)

# %%
result['TAVG'] = result.apply(lambda row: ((row['TMAX']+row['TMIN'])/2) if np.isnan(row['TAVG']) else row['TAVG'],axis=1)

# %%
df1
# Out:
# Empty DataFrame
# Columns: [Datetime, start_station_id, AVG_WND_SPEED, Bike Score, COUNT, FOG, HOLIDAY, Neighborhood, PRCP, Population, SLEET_OR_HAIL, SNOW, SNOW_DEPTH, TAVG, THUNDER, TMAX, TMIN, Transit Score, WEEKDAY, Walk Score, hour_of_day, month, start_lat, start_lon, COUNT_BINS]
# Index: []
#
# [0 rows x 25 columns]

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
X = result[['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED', 'PRCP', 'SNOW', 'SNOW_DEPTH', 'TAVG', 'TMAX', 'TMIN', 'FOG', 'THUNDER', 'SLEET_OR_HAIL', 'month', 'WEEKDAY', 'HOLIDAY', 'Walk Score', 'Transit Score', 'Bike Score']]
normalized_X = preprocessing.normalize(X)
y = result['COUNT_BINS'].astype(str)

X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.3)

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
encoded_y = preprocessing.LabelEncoder().fit_transform(y_train)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_x = ohe.fit_transform(X_train)

encoded_test_y = preprocessing.LabelEncoder().fit_transform(y_test)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_test_x = ohe.fit_transform(X_test)
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=125, max_depth=5, random_state=0)
clf.fit(encoded_x, encoded_y)  
clf.score(encoded_test_x, encoded_test_y)
# Out:
# 0.6104195346143543

# %%
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.3)

# %%
#feature importance
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier(n_estimators=10)
model.fit(normalized_X, y)
print(model.feature_importances_)
# Out:
# [0.07698863 0.07826934 0.14752862 0.06569592 0.0230282  0.0009676
#  0.0012824  0.06956424 0.0705085  0.07016144 0.02621194 0.00802788
#  0.0005205  0.0662118  0.05336263 0.00273796 0.0803385  0.07835823
#  0.08023568]

# %%
X = result[['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'FOG', 'month', 'WEEKDAY', 'HOLIDAY', 'Walk Score', 'Transit Score', 'Bike Score']]
normalized_X = preprocessing.normalize(X)
y = result['COUNT_BINS'].astype(str)

X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.3)
encoded_y = preprocessing.LabelEncoder().fit_transform(y_train)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_x = ohe.fit_transform(X_train)

encoded_test_y = preprocessing.LabelEncoder().fit_transform(y_test)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_test_x = ohe.fit_transform(X_test)

            
clf = RandomForestClassifier(n_estimators=125, max_depth=5, random_state=0)
clf.fit(encoded_x, encoded_y)  
clf.score(encoded_test_x, encoded_test_y)
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# ...

# %%
model = ExtraTreesClassifier(n_estimators=10)
model.fit(normalized_X, y)
print(model.feature_importances_)
# Out:
# [0.07412047 0.07993022 0.17905495 0.06374707 0.02673012 0.06738554
#  0.06638275 0.0662379  0.02683528 0.06408226 0.05081663 0.00531551
#  0.08074527 0.07284323 0.07577278]

# %%
X = result[['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'FOG', 'month', 'WEEKDAY', 'Walk Score', 'Transit Score', 'Bike Score']]
normalized_X = preprocessing.normalize(X)
y = result['COUNT_BINS'].astype(str)

X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.3)
encoded_y = preprocessing.LabelEncoder().fit_transform(y_train)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_x = ohe.fit_transform(X_train)

encoded_test_y = preprocessing.LabelEncoder().fit_transform(y_test)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_test_x = ohe.fit_transform(X_test)

            
clf = RandomForestClassifier(n_estimators=125, max_depth=5, random_state=0)
clf.fit(encoded_x, encoded_y)  
clf.score(encoded_test_x, encoded_test_y)
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# ...

# %%
import xgboost as xgb
model1 = xgb.XGBClassifier()


train_model1 = model1.fit(X_train, y_train)
train_model1.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-162-fc1587a90d61> in <module>
#       3
#       4
# ----> 5 train_model1 = model1.fit(X_train, y_train)
#       6 train_model1.score(X_test, y_test)
#
# ~/anaconda3/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# ...

# %%
result.columns.values
# Out:
# array(['AVG_WND_SPEED', 'Bike Score', 'COUNT', 'Datetime', 'FOG',
#        'HOLIDAY', 'Neighborhood', 'PRCP', 'Population', 'SLEET_OR_HAIL',
#        'SNOW', 'SNOW_DEPTH', 'TAVG', 'THUNDER', 'TMAX', 'TMIN',
#        'Transit Score', 'WEEKDAY', 'Walk Score', 'hour_of_day', 'month',
#        'start_lat', 'start_lon', 'start_station_id', 'COUNT_BINS'],
#       dtype=object)

# %%
#need to better balance data, rebucket classes
deletedf = result.loc[(result['COUNT'] == 1) & (result.index%3)]
deletedf
# Out:
#                     Datetime  start_station_id  AVG_WND_SPEED  Bike Score  \
# 25       2015-04-23 12:00:00            3057.0          15.21        75.0
# 34       2015-04-23 13:00:00            3020.0          15.21        88.0
# 46       2015-04-23 13:00:00            3043.0          15.21        76.0
# 70       2015-04-23 14:00:00            3022.0          15.21        90.0
# 76       2015-04-23 14:00:00            3033.0          15.21        83.0
# ...                      ...               ...            ...         ...
# 1653634  2019-09-30 23:00:00            3062.0           7.61        94.0
# 1653637  2019-09-30 23:00:00            3073.0           7.61        90.0
# 1653640  2019-09-30 23:00:00            3102.0           7.61        91.0
# 1653643  2019-09-30 23:00:00            3123.0           7.61        65.0
# 1653646  2019-09-30 23:00:00            3168.0           7.61        98.0
#
#          COUNT  FOG  HOLIDAY             Neighborhood  PRCP  Population  ...  \
# ...

# %%
#deletedf = result.loc[(result['COUNT_BINS'] == '0') ]
#deletedf
# Out:
#                    Datetime  start_station_id  AVG_WND_SPEED  Bike Score  \
# 135927  2019-08-18 12:00:00            3160.0           5.14        98.0
# 135928  2019-08-18 12:00:00            3165.0           5.14        79.0
# 135929  2019-08-18 13:00:00            3048.0           5.14        88.0
# 135930  2019-08-18 13:00:00            3100.0           5.14        89.0
# 135931  2019-08-18 13:00:00            3154.0           5.14        80.0
# ...                     ...               ...            ...         ...
# 140008  2019-09-30 23:00:00            3036.0           7.61        96.0
# 140009  2019-09-30 23:00:00            3071.0           7.61        91.0
# 140010  2019-09-30 23:00:00            3109.0           7.61        86.0
# 140011  2019-09-30 23:00:00            3161.0           7.61        90.0
# 140012  2019-09-30 23:00:00            3200.0           7.61        73.0
#
#         COUNT           Datetime.1  FOG  HOLIDAY  \
# ...

# %%
result = pd.concat([result, deletedf, deletedf]).drop_duplicates(keep=False)

# %%
result = result.reset_index(drop=True)

# %%
result
# Out:
#                     Datetime  start_station_id  AVG_WND_SPEED  Bike Score  \
# 0        2015-04-23 07:00:00            3004.0          15.21        77.0
# 1        2015-04-23 07:00:00            3031.0          15.21        74.0
# 2        2015-04-23 07:00:00            3039.0          15.21        78.0
# 3        2015-04-23 07:00:00            3046.0          15.21        97.0
# 4        2015-04-23 07:00:00            3048.0          15.21        88.0
# ...                      ...               ...            ...         ...
# 1409630  2019-09-30 23:00:00            3156.0           7.61        86.0
# 1409631  2019-09-30 23:00:00            3190.0           7.61        85.0
# 1409632  2019-09-30 23:00:00            3192.0           7.61        97.0
# 1409633  2019-09-30 23:00:00            3200.0           7.61        73.0
# 1409634  2019-09-30 23:00:00            3209.0           7.61        99.0
#
#          COUNT  FOG  HOLIDAY                   Neighborhood  PRCP  Population  \
# ...

# %%
result.COUNT_BINS.value_counts()
# Out:
# 0-2    1379696
# 3-9     363317
# 10+      15498
# Name: COUNT_BINS, dtype: int64

# %%
df.COUNT_BINS.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-efad443140a7> in <module>
# ----> 1 df.COUNT_BINS.value_counts()
#
# NameError: name 'df' is not defined

# %%
result.COUNT.value_counts()
# Out:
# 1.0     732447
# 2.0     332545
# 0.0     314704
# 3.0     162813
# 4.0      87401
# 5.0      48910
# 6.0      28521
# 7.0      17653
# 8.0      10962
# 9.0       7057
# 10.0      4694
# 11.0      3206
# 12.0      2208
# 13.0      1484
# 14.0      1006
# 15.0       732
# 16.0       526
# 17.0       367
# 18.0       278
# 19.0       199
# 20.0       148
# 21.0       111
# 22.0        95
# 24.0        75
# 23.0        65
# 26.0        44
# 25.0        42
# 28.0        32
# 27.0        27
# 29.0        26
# 30.0        26
# 31.0        21
# 32.0        15
# 34.0        11
# 35.0        10
# 33.0         9
# 41.0         5
# 37.0         5
# 36.0         4
# 38.0         3
# 39.0         3
# 48.0         3
# 49.0         3
# 42.0         2
# 46.0         2
# 40.0         2
# 78.0         1
# 50.0         1
# 51.0         1
# 52.0         1
# 53.0         1
# 57.0         1
# 60.0         1
# 61.0         1
# 45.0         1
# Name: COUNT, dtype: int64

# %%
#THIS IS THE ONE! with result3
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X = result[['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED', 'TAVG', 'TMAX', 'TMIN', 'month', 'WEEKDAY', 'Walk Score', 'Transit Score', 'Bike Score']]
normalized_X = preprocessing.normalize(X)
y = result['COUNT_BINS'].astype(str)

X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.3)
#encoded_y = preprocessing.LabelEncoder().fit_transform(y_train)
#ohe = preprocessing.OneHotEncoder(sparse=False)
#encoded_x = ohe.fit_transform(X_train)

#encoded_test_y = preprocessing.LabelEncoder().fit_transform(y_test)
#ohe = preprocessing.OneHotEncoder(sparse=False)
#encoded_test_x = ohe.fit_transform(X_test)

            
clf = RandomForestClassifier(n_estimators=125, max_depth=5, random_state=0)
clf = clf.fit(X_train, y_train)  
clf.score(X_test, y_test)
# Out:
# 0.7841453197208248

# %%
import pickle
filename = 'random_forest_classifier_2.pkl'
pickle.dump(clf, open(filename, 'wb'))

# %%
from sklearn.metrics import f1_score
y_pred = clf.predict(X_test)
f1_score(y_test, y_pred, average='weighted')
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.6892755602848414

# %%
from sklearn.metrics import classification_report
y_pred = clf.predict(X_test)
#target_names = ['0-2', '3-9', '10+']
print(classification_report(y_test, y_pred,))
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          0-2       0.78      1.00      0.88    413679
#          10+       0.00      0.00      0.00      4705
#          3-9       0.00      0.00      0.00    109170
#
#     accuracy                           0.78    527554
#    macro avg       0.26      0.33      0.29    527554
# weighted avg       0.61      0.78      0.69    527554

# %%
unique, counts = np.unique(encoded_test_y, return_counts=True)
print(np.asarray((unique, counts)).T)

unique, counts = np.unique(y_pred, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[     0  63209]
#  [     1 146780]
#  [     2   4699]
#  [     3  99741]
#  [     4 108462]]
# [[     1 422891]]

# %%
model = ExtraTreesClassifier(n_estimators=10)
model.fit(normalized_X, y)
print(model.feature_importances_)
# Out:
# [0.07789687 0.08651648 0.14496984 0.07283084 0.07665576 0.07851337
#  0.07523235 0.07335641 0.06015964 0.08581763 0.08426424 0.08378658]

# %%
df = pd.read_csv("result.csv")
df
# Out:
#         Unnamed: 0             Datetime  start_station_id  AVG_WND_SPEED  \
# 0                0  2015-04-23 07:00:00            3004.0          15.21
# 1                1  2015-04-23 07:00:00            3039.0          15.21
# 2                2  2015-04-23 07:00:00            3066.0          15.21
# 3                3  2015-04-23 10:00:00            3023.0          15.21
# 4                4  2015-04-23 10:00:00            3032.0          15.21
# ...            ...                  ...               ...            ...
# 807069      807069  2019-09-30 23:00:00            3057.0           7.61
# 807070      807070  2019-09-30 23:00:00            3059.0           7.61
# 807071      807071  2019-09-30 23:00:00            3123.0           7.61
# 807072      807072  2019-09-30 23:00:00            3190.0           7.61
# 807073      807073  2019-09-30 23:00:00            3192.0           7.61
#
#         Bike Score  COUNT           Datetime.1  FOG  HOLIDAY  \
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'Datetime', 'start_station_id', 'AVG_WND_SPEED',
#        'Bike Score', 'COUNT', 'Datetime.1', 'FOG', 'HOLIDAY',
#        'Neighborhood', 'PRCP', 'Population', 'SLEET_OR_HAIL', 'SNOW',
#        'SNOW_DEPTH', 'TAVG', 'THUNDER', 'TMAX', 'TMIN', 'Transit Score',
#        'WEEKDAY', 'Walk Score', 'hour_of_day', 'month', 'start_lat',
#        'start_lon', 'start_station_id.1', 'COUNT_BINS'], dtype=object)

# %%
X = df[['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'FOG', 'month', 'WEEKDAY', 'Walk Score', 'Transit Score', 'Bike Score']]
normalized_X = preprocessing.normalize(X)
y = df['COUNT_BINS'].astype(str)

X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.3)
encoded_y = preprocessing.LabelEncoder().fit_transform(y_train)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_x = ohe.fit_transform(X_train)

encoded_test_y = preprocessing.LabelEncoder().fit_transform(y_test)
ohe = preprocessing.OneHotEncoder(sparse=False)
encoded_test_x = ohe.fit_transform(X_test)

            
clf = RandomForestClassifier(n_estimators=125, max_depth=5, random_state=0)
clf = clf.fit(encoded_x, encoded_y)  
clf.score(encoded_test_x, encoded_test_y)
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# ...

# %%
from sklearn.metrics import classification_report
y_pred = clf.predict(encoded_test_x)
#target_names = ['0-2', '3-9', '10+']
print(classification_report(encoded_test_y, y_pred,))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     84394
#            1       0.00      0.00      0.00      3203
#            2       0.49      1.00      0.66    119258
#            3       0.00      0.00      0.00     35268
#
#     accuracy                           0.49    242123
#    macro avg       0.12      0.25      0.17    242123
# weighted avg       0.24      0.49      0.33    242123
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
unique, counts = np.unique(encoded_test_y, return_counts=True)
print(np.asarray((unique, counts)).T)

unique, counts = np.unique(y_pred, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[     0  84044]
#  [     1   3205]
#  [     2 119590]
#  [     3  35284]]
# [[     2 242123]]

# %%
import pandas as pd
result = pd.read_csv("result3.csv")

# %%
X = result[['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED','PRCP', 'TAVG', 'TMAX', 'TMIN', 'month', 'WEEKDAY', 'Walk Score', 'Transit Score', 'Bike Score']]
normalized_X = preprocessing.normalize(X)
y = result['COUNT_BINS'].astype(str)

X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size = 0.3)

# %%
from sklearn import tree 
decisionTree = tree.DecisionTreeClassifier(min_impurity_decrease=0)
decisionTree.fit(X_train, y_train)
decisionTree.score(X_test, y_test)
# Out:
# 0.7359246636363291

# %%
from sklearn.metrics import classification_report
y_pred = decisionTree.predict(X_test)
#target_names = ['0-2', '3-9', '10+']
print(classification_report(y_test, y_pred,))
# Out:
#               precision    recall  f1-score   support
#
#          0-2       0.84      0.83      0.84    413778
#          10+       0.20      0.21      0.21      4620
#          3-9       0.38      0.39      0.39    109156
#
#     accuracy                           0.74    527554
#    macro avg       0.47      0.48      0.48    527554
# weighted avg       0.74      0.74      0.74    527554

# %%
from sklearn.metrics import classification_report
y_pred = decisionTree.predict(X_test)
#target_names = ['0-2', '3-9', '10+']
print(classification_report(y_test, y_pred,))
# Out:
#               precision    recall  f1-score   support
#
#          0-2       0.84      0.83      0.84    413840
#          10+       0.20      0.22      0.21      4587
#          3-9       0.38      0.39      0.38    109127
#
#     accuracy                           0.74    527554
#    macro avg       0.47      0.48      0.48    527554
# weighted avg       0.74      0.74      0.74    527554

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.datasets import load_wine
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

# %%
graph = Source(tree.export_graphviz(decisionTree, out_file=None
   , feature_names=['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'FOG', 'month', 'WEEKDAY', 'Walk Score', 'Transit Score', 'Bike Score'] , class_names=['0-1', '2-4', '5-10', '11+'] 
   , filled = True))
display(SVG(graph.pipe(format='svg')))

# %%
len(clf.estimators_)
# Out:
# 125

# %%
import graphviz
#from sklearn.tree import DecisionTreeClassifier()
from sklearn import tree

dot_data = tree.export_graphviz(clf.estimators_[100],out_file=None,feature_names=['start_lat', 'start_lon', 'hour_of_day', 'AVG_WND_SPEED', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'FOG', 'month', 'WEEKDAY', 'Walk Score', 'Transit Score', 'Bike Score'] , class_names=['0-1', '2-4', '5-10', '11+'])
graph = graphviz.Source(dot_data)
graph.render("image",view=True)
# Out:
# 'image.pdf'

# %%
import xgboost as xgb
model1 = xgb.XGBClassifier()
train_model1 = model1.fit(X_train, y_train)
train_model1.score(X_test, y_test)
# Out:
# 0.7865545517615259

# %%
from sklearn.metrics import classification_report
y_pred = train_model1.predict(X_test)
#target_names = ['0-2', '3-9', '10+']
print(classification_report(y_test, y_pred,))
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          0-2       0.79      1.00      0.88    413679
#          10+       0.00      0.00      0.00      4705
#          3-9       0.58      0.03      0.05    109170
#
#     accuracy                           0.79    527554
#    macro avg       0.46      0.34      0.31    527554
# weighted avg       0.74      0.79      0.70    527554

# %%
[{0: 1, 1: 1}, {0: 1, 1: 10}, {0: 1, 1: 100}]
