# %%
import pandas as pd
import numpy as np
import os

# %%
# %pwd
# Out:
# '/home/rebecca/Grad_School_Work/CSC_8515_Machine_Learning/final_project/philly_bike_share_demand/data'

# %%
df_2015q2 = pd.read_csv("raw_data/2015Q2.csv")
df_2015q3 = pd.read_csv("raw_data/2015Q3.csv")
df_2015q4 = pd.read_csv("raw_data/2015Q4.csv")
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2015q2
# Out:
#         trip_id  duration     start_time       end_time  start_station_id  \
# 0       4001912        60   4/23/15 7:44   4/23/15 7:45              3046
# 1       4001916        60   4/23/15 7:45   4/23/15 7:46              3046
# 2       4001918       120   4/23/15 7:46   4/23/15 7:48              3057
# 3       4001938        60  4/23/15 10:13  4/23/15 10:14              3004
# 4       4001955       180  4/23/15 10:14  4/23/15 10:17              3004
# ...         ...       ...            ...            ...               ...
# 119554  4150090       480  6/30/15 23:25  6/30/15 23:33              3026
# 119555  4150097       960  6/30/15 23:33  6/30/15 23:49              3022
# 119556  4150099       420  6/30/15 23:41  6/30/15 23:48              3023
# 119557  4150100       480  6/30/15 23:48  6/30/15 23:56              3026
# 119558  4150101       240  6/30/15 23:49  6/30/15 23:53              3063
#
#         start_lat  start_lon  end_station_id   end_lat   end_lon  bike_id  \
# ...

# %%
df_2015q3
# Out:
#         trip_id  duration     start_time       end_time  start_station_id  \
# 0       4150104       660    7/1/15 0:06    7/1/15 0:17              3068
# 1       4150105       780    7/1/15 0:10    7/1/15 0:23              3047
# 2       4150106       120    7/1/15 0:14    7/1/15 0:16              3057
# 3       4150107       480    7/1/15 0:15    7/1/15 0:23              3039
# 4       4150108      5280    7/1/15 0:16    7/1/15 1:44              3057
# ...         ...       ...            ...            ...               ...
# 188363  4376424       480  9/30/15 23:42  9/30/15 23:50              3060
# 188364  4376425       660  9/30/15 23:45  9/30/15 23:56              3055
# 188365  4376426       300  9/30/15 23:47  9/30/15 23:52              3061
# 188366  4376429       300  9/30/15 23:49  9/30/15 23:54              3055
# 188367  4376430       120  9/30/15 23:51  9/30/15 23:53              3050
#
#         start_lat  start_lon  end_station_id   end_lat   end_lon bike_id  \
# ...

# %%
df_2015q4
# Out:
#         trip_id  duration      start_time        end_time  start_station_id  \
# 0       4376433      1140    10/1/15 0:04    10/1/15 0:23              3041
# 1       4376434       720    10/1/15 0:08    10/1/15 0:20              3045
# 2       4376435       600    10/1/15 0:27    10/1/15 0:37              3060
# 3       4376437       840    10/1/15 0:36    10/1/15 0:50              3052
# 4       4376438       360    10/1/15 0:37    10/1/15 0:43              3017
# ...         ...       ...             ...             ...               ...
# 121778  4516677       960  12/31/15 23:33  12/31/15 23:49              3030
# 121779  4516678       660  12/31/15 23:34  12/31/15 23:45              3049
# 121780  4516679       540  12/31/15 23:36  12/31/15 23:45              3074
# 121781  4516684       360  12/31/15 23:41  12/31/15 23:47              3028
# 121782  4516685       420  12/31/15 23:42  12/31/15 23:49              3073
#
# ...

# %%
result = df_2015q2.append([df_2015q3, df_2015q4])

# %%
result
# Out:
#         trip_id  duration      start_time        end_time  start_station_id  \
# 0       4001912        60    4/23/15 7:44    4/23/15 7:45              3046
# 1       4001916        60    4/23/15 7:45    4/23/15 7:46              3046
# 2       4001918       120    4/23/15 7:46    4/23/15 7:48              3057
# 3       4001938        60   4/23/15 10:13   4/23/15 10:14              3004
# 4       4001955       180   4/23/15 10:14   4/23/15 10:17              3004
# ...         ...       ...             ...             ...               ...
# 121778  4516677       960  12/31/15 23:33  12/31/15 23:49              3030
# 121779  4516678       660  12/31/15 23:34  12/31/15 23:45              3049
# 121780  4516679       540  12/31/15 23:36  12/31/15 23:45              3074
# 121781  4516684       360  12/31/15 23:41  12/31/15 23:47              3028
# 121782  4516685       420  12/31/15 23:42  12/31/15 23:49              3073
#
# ...

# %%
len(result.trip_id.unique())
# Out:
# 429710

# %%
len(result.bike_id.unique())
# Out:
# 1326

# %%
result2015 = result.drop(['trip_id', 'plan_duration', 'duration', 'trip_route_category', 'passholder_type', 'end_station_id', 'end_lat', 'end_lon'], axis=1)

# %%
df_2016q1 = pd.read_csv("raw_data/2016Q1.csv")
df_2016q2 = pd.read_csv("raw_data/2016Q2.csv")
df_2016q3 = pd.read_csv("raw_data/2016Q3.csv")
df_2016q4 = pd.read_csv("raw_data/2016Q4.csv")

# %%
df_2016q1.shape
# Out:
# (73169, 14)

# %%
df_2016q2.shape
# Out:
# (170824, 14)

# %%
df_2016q3.shape
# Out:
# (234946, 14)

# %%
df_2016q4.shape
# Out:
# (176119, 14)

# %%
result2016 = df_2016q1.append([df_2016q2, df_2016q3, df_2016q4])

# %%
result2016
# Out:
#          trip_id  duration        start_time          end_time  \
# 0        4516691       600     1/1/2016 0:04     1/1/2016 0:14
# 1        4516692      1320     1/1/2016 0:07     1/1/2016 0:29
# 2        4516693       780     1/1/2016 0:14     1/1/2016 0:27
# 3        4516694      1320     1/1/2016 0:20     1/1/2016 0:42
# 4        4516695       600     1/1/2016 0:20     1/1/2016 0:30
# ...          ...       ...               ...               ...
# 176114  87530168       240  12/31/2016 23:35  12/31/2016 23:39
# 176115  87530167       360  12/31/2016 23:40  12/31/2016 23:46
# 176116  87530166       300  12/31/2016 23:45  12/31/2016 23:50
# 176117  87535957      1500  12/31/2016 23:47     1/1/2017 0:12
# 176118  87535956      1500  12/31/2016 23:55     1/1/2017 0:20
#
#         start_station_id start_lat start_lon  end_station_id  end_lat  \
# 0                 3046.0   39.9501  -75.1447            3041  39.9685
# ...

# %%
result2016 = result2016.drop(['trip_id', 'plan_duration', 'duration', 'trip_route_category', 'passholder_type', 'end_station_id', 'end_lat', 'end_lon'], axis=1)

# %%
df_2017q1 = pd.read_csv("raw_data/2017Q1.csv")
df_2017q2 = pd.read_csv("raw_data/2017Q2.csv")
df_2017q3 = pd.read_csv("raw_data/2017Q3.csv")
df_2017q4 = pd.read_csv("raw_data/2017Q4.csv")

# %%
print(df_2017q1.columns.values)
print(df_2017q2.columns.values)
print(df_2017q3.columns.values)
print(df_2017q4.columns.values)
print(df_2015q4.columns.values)
print(df_2016q4.columns.values)
# Out:
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
# ...

# %%
df_2017q2 = df_2017q2.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})
df_2017q3 = df_2017q3.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})
df_2017q4 = df_2017q4.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})

# %%
df_2017q1.shape
# Out:
# (107772, 14)

# %%
df_2017q2.shape
# Out:
# (220441, 14)

# %%
df_2017q3.shape
# Out:
# (276785, 14)

# %%
df_2017q4.shape
# Out:
# (183909, 14)

# %%
result2017 = df_2017q1.append([df_2017q2, df_2017q3, df_2017q4])

# %%
result2017 = result2017.drop(['trip_id', 'plan_duration', 'duration', 'trip_route_category', 'passholder_type', 'end_station_id', 'end_lat', 'end_lon'], axis=1)

# %%
df_2018q1 = pd.read_csv("raw_data/2018Q1.csv")
df_2018q2 = pd.read_csv("raw_data/2018Q2.csv")
df_2018q3 = pd.read_csv("raw_data/2018Q3.csv")
df_2018q4 = pd.read_csv("raw_data/2018Q4.csv")
# Out:
# /home/rebecca/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df_2018q1.columns.values)
print(df_2018q2.columns.values)
print(df_2018q3.columns.values)
print(df_2018q4.columns.values)
print(df_2015q4.columns.values)
print(df_2016q4.columns.values)
# Out:
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type' 'bike_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type' 'bike_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
# ...

# %%
df_2018q1 = df_2018q1.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})
df_2018q2 = df_2018q2.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})
df_2018q3 = df_2018q3.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})
df_2018q4 = df_2018q4.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})

# %%
df_2018q4.bike_type.unique()
# Out:
# array(['standard', 'electric'], dtype=object)

# %%
result2018 = df_2018q1.append([df_2018q2, df_2018q3, df_2018q4])

# %%
result2018 = result2018.drop(['trip_id', 'plan_duration', 'duration', 'trip_route_category', 'passholder_type', 'end_station_id', 'end_lat', 'end_lon', 'bike_type'], axis=1)

# %%
result2018
# Out:
#        bike_id             end_time  start_lat  start_lon  start_station_id  \
# 0         3708  2018-01-01 00:42:00  39.952950 -75.139793              3124
# 1         3288  2018-01-01 10:10:00  39.950481 -75.172859              3023
# 2        11735  2018-01-01 01:10:00  39.941380 -75.145638              3026
# 3         5202  2018-01-01 01:24:00  39.947922 -75.162369              3045
# 4         5142  2018-01-01 01:09:00  39.972630 -75.167572              3115
# ...        ...                  ...        ...        ...               ...
# 142867   14519  2019-01-01 00:04:00  39.954239 -75.161377              3037
# 142868   11891  2019-01-01 00:06:00  39.951340 -75.173943              3168
# 142869    5410  2019-01-01 06:44:00  39.941380 -75.145638              3026
# 142870    2701  2018-12-31 23:47:00  39.946331 -75.169800              3063
# 142871    3471  2018-12-31 23:49:00  39.945171 -75.159927              3007
#
#                  start_time
# ...

# %%
df_2019q1 = pd.read_csv("raw_data/2019Q1.csv")
df_2019q2 = pd.read_csv("raw_data/2019Q2.csv")
df_2019q3 = pd.read_csv("raw_data/2019Q3.csv")

# %%
print(df_2019q1.columns.values)
print(df_2019q2.columns.values)
print(df_2019q3.columns.values)
print(df_2015q4.columns.values)
# Out:
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type' 'bike_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type' 'bike_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type' 'bike_type']
# ['trip_id' 'duration' 'start_time' 'end_time' 'start_station_id'
#  'start_lat' 'start_lon' 'end_station_id' 'end_lat' 'end_lon' 'bike_id'
#  'plan_duration' 'trip_route_category' 'passholder_type']

# %%
df_2019q1 = df_2019q1.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})
df_2019q2 = df_2019q2.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})
df_2019q3 = df_2019q3.rename(columns={"start_station": "start_station_id", "end_station": "end_station_id"})

# %%
result2019 = df_2019q1.append([df_2019q2, df_2019q3])

# %%
result2019 = result2019.drop(['trip_id', 'plan_duration', 'duration', 'trip_route_category', 'passholder_type', 'end_station_id', 'end_lat', 'end_lon', 'bike_type'], axis=1)

# %%
result2019
# Out:
#                  start_time             end_time  start_station_id  start_lat  \
# 0       2019-01-01 00:19:00  2019-01-01 00:27:00              3049  39.945091
# 1       2019-01-01 00:30:00  2019-01-01 00:37:00              3005  39.947330
# 2       2019-01-01 00:52:00  2019-01-01 01:05:00              3166  39.972351
# 3       2019-01-01 00:55:00  2019-01-01 01:04:00              3058  39.967159
# 4       2019-01-01 01:05:00  2019-01-01 01:17:00              3182  39.950809
# ...                     ...                  ...               ...        ...
# 275192      9/30/2019 23:52       10/1/2019 1:18              3012  39.942181
# 275193      9/30/2019 23:52       10/1/2019 0:06              3057  39.964390
# 275194      9/30/2019 23:55      9/30/2019 23:56              3059  39.962650
# 275195      9/30/2019 23:56       10/1/2019 0:07              3059  39.962650
# 275196      9/30/2019 23:59       10/1/2019 0:05              3053  39.932308
#
#         start_lon  bike_id
# ...

# %%
result = result2015.append([result2016, result2017, result2018, result2019])

# %%
result
# Out:
#        bike_id         end_time start_lat start_lon  start_station_id  \
# 0         3350     4/23/15 7:45   39.9501  -75.1447            3046.0
# 1         3350     4/23/15 7:46   39.9501  -75.1447            3046.0
# 2         3282     4/23/15 7:48   39.9644    -75.18            3057.0
# 3         3350    4/23/15 10:14   39.9538  -75.1637            3004.0
# 4         2716    4/23/15 10:17   39.9538  -75.1637            3004.0
# ...        ...              ...       ...       ...               ...
# 275192    3303   10/1/2019 1:18   39.9422  -75.1775            3012.0
# 275193    5194   10/1/2019 0:06   39.9644  -75.1799            3057.0
# 275194    5219  9/30/2019 23:56   39.9626  -75.1617            3059.0
# 275195    6694   10/1/2019 0:07   39.9626  -75.1617            3059.0
# 275196   19946   10/1/2019 0:05   39.9323  -75.1815            3053.0
#
#              start_time
# 0          4/23/15 7:44
# 1          4/23/15 7:45
# 2          4/23/15 7:46
# 3         4/23/15 10:13
# ...

# %%
result.to_csv("clean_data.csv")
